# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# WARNING:tensorflow:From <ipython-input-1-76cba88990fd>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TM/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TM/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TM/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TM/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TM/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y_i, f(x_i; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        loss = -tf.reduce_mean(tf.reduce_sum((y_true * tf.log(y_hat)), axis = 1))
        loss = -tf.reduce_mean(tf.reduce_sum(y_true * tf.log(y_hat), axis = 1))
    return loss

y_true = tf.placeholder(tf.float32, [None, 10])
y_hat = tf.placeholder(tf.float32, [None, 10])
get_cross_entropy_loss(y_true, y_hat)


def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.001
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """
    with tf.variable_scope(name):
        shp = inputs.get_shape().as_list()[-1]
        initials = tf.truncated_normal([shp, out_dim], stddev = 0.01)
        weight = tf.get_variable('w', initializer = initials)

        initials = tf.constant(1.0 , shape = [out_dim])
        bias = tf.get_variable('b', initializer = initials)
        result = tf.matmul(inputs, weight) + bias
        return result

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
#train_data = None
#test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################
x = tf.placeholder(tf.float32, [None, 784])
y_true = tf.placeholder(tf.float32, [None, 10])

###################################################################
#                    Implementation 3-3                          #
###################################################################

h1 = fc('layer1', 512, x)
h1 = tf.nn.relu(h1)
h2 = fc('layer2', 64, h1)
h2 = tf.nn.relu(h2)
y_logits = fc('layer3', 10, h2)
y_hat = tf.nn.softmax(y_logits)

###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true, y_hat)


# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()


with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _ = sess.run(train_step, feed_dict={x: batch_x, y_true: batch_y})
        loss = sess.run(cross_entropy, feed_dict={x: batch_x, y_true: batch_y})
 
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 2.2964, test accuracy: 0.0974
# 20th iteration, loss: 2.2094, test accuracy: 0.1829
# 30th iteration, loss: 1.9306, test accuracy: 0.2486
# 40th iteration, loss: 1.6884, test accuracy: 0.3964
# 50th iteration, loss: 1.3825, test accuracy: 0.4285
# 60th iteration, loss: 1.1556, test accuracy: 0.5512
# 70th iteration, loss: 0.7841, test accuracy: 0.6537
# 80th iteration, loss: 0.6864, test accuracy: 0.7532
# 90th iteration, loss: 0.5338, test accuracy: 0.8089
# 100th iteration, loss: 0.3158, test accuracy: 0.8640
# 110th iteration, loss: 0.3465, test accuracy: 0.8825
# 120th iteration, loss: 0.4603, test accuracy: 0.8908
# 130th iteration, loss: 0.3245, test accuracy: 0.9094
# 140th iteration, loss: 0.3203, test accuracy: 0.8957
# 150th iteration, loss: 0.2615, test accuracy: 0.9151
# 160th iteration, loss: 0.2819, test accuracy: 0.9222
# 170th iteration, loss: 0.2008, test accuracy: 0.9199
# 180th iteration, loss: 0.3248, test accuracy: 0.9295
# 190th iteration, loss: 0.1634, test accuracy: 0.9327
# 200th iteration, loss: 0.1616, test accuracy: 0.9358
# 210th iteration, loss: 0.2213, test accuracy: 0.9378
# 220th iteration, loss: 0.2052, test accuracy: 0.9313
# 230th iteration, loss: 0.2009, test accuracy: 0.9360
# 240th iteration, loss: 0.1189, test accuracy: 0.9386
# 250th iteration, loss: 0.2722, test accuracy: 0.9380
# 260th iteration, loss: 0.1442, test accuracy: 0.9375
# 270th iteration, loss: 0.2339, test accuracy: 0.9411
# 280th iteration, loss: 0.0886, test accuracy: 0.9373
# 290th iteration, loss: 0.1349, test accuracy: 0.9406
# 300th iteration, loss: 0.1006, test accuracy: 0.9449
# 310th iteration, loss: 0.0859, test accuracy: 0.9485
# 320th iteration, loss: 0.1457, test accuracy: 0.9511
# 330th iteration, loss: 0.1106, test accuracy: 0.9475
# 340th iteration, loss: 0.1439, test accuracy: 0.9446
# 350th iteration, loss: 0.1700, test accuracy: 0.9403
# 360th iteration, loss: 0.1060, test accuracy: 0.9431
# 370th iteration, loss: 0.1964, test accuracy: 0.9461
# 380th iteration, loss: 0.1626, test accuracy: 0.9418
# 390th iteration, loss: 0.1553, test accuracy: 0.9467
# 400th iteration, loss: 0.1906, test accuracy: 0.9438
# 410th iteration, loss: 0.1673, test accuracy: 0.9517
# 420th iteration, loss: 0.1063, test accuracy: 0.9532
# 430th iteration, loss: 0.0918, test accuracy: 0.9476
# 440th iteration, loss: 0.1113, test accuracy: 0.9530
# 450th iteration, loss: 0.1360, test accuracy: 0.9513
# 460th iteration, loss: 0.1819, test accuracy: 0.9395
# 470th iteration, loss: 0.0862, test accuracy: 0.9502
# 480th iteration, loss: 0.1681, test accuracy: 0.9532
# 490th iteration, loss: 0.1128, test accuracy: 0.9535
# 500th iteration, loss: 0.0978, test accuracy: 0.9558
# 510th iteration, loss: 0.1490, test accuracy: 0.9546
# 520th iteration, loss: 0.0532, test accuracy: 0.9576
# 530th iteration, loss: 0.0308, test accuracy: 0.9573
# 540th iteration, loss: 0.1351, test accuracy: 0.9594
# 550th iteration, loss: 0.0924, test accuracy: 0.9562
# 560th iteration, loss: 0.0900, test accuracy: 0.9545
# 570th iteration, loss: 0.0949, test accuracy: 0.9528
# 580th iteration, loss: 0.0789, test accuracy: 0.9597
# 590th iteration, loss: 0.1195, test accuracy: 0.9595
# 600th iteration, loss: 0.0635, test accuracy: 0.9570
# 610th iteration, loss: 0.1032, test accuracy: 0.9603
# 620th iteration, loss: 0.1101, test accuracy: 0.9608
# 630th iteration, loss: 0.0154, test accuracy: 0.9611
# 640th iteration, loss: 0.0449, test accuracy: 0.9539
# 650th iteration, loss: 0.0450, test accuracy: 0.9576
# 660th iteration, loss: 0.0507, test accuracy: 0.9595
# 670th iteration, loss: 0.0452, test accuracy: 0.9485
# 680th iteration, loss: 0.1654, test accuracy: 0.9570
# 690th iteration, loss: 0.0409, test accuracy: 0.9580
# 700th iteration, loss: 0.1217, test accuracy: 0.9571
# 710th iteration, loss: 0.1600, test accuracy: 0.9579
# 720th iteration, loss: 0.0926, test accuracy: 0.9543
# 730th iteration, loss: 0.2254, test accuracy: 0.9503
# 740th iteration, loss: 0.0611, test accuracy: 0.9582
# 750th iteration, loss: 0.1113, test accuracy: 0.9566
# 760th iteration, loss: 0.0962, test accuracy: 0.9569
# 770th iteration, loss: 0.0766, test accuracy: 0.9599
# 780th iteration, loss: 0.1284, test accuracy: 0.9621
# 790th iteration, loss: 0.0792, test accuracy: 0.9607
# 800th iteration, loss: 0.1219, test accuracy: 0.9581
# 810th iteration, loss: 0.1336, test accuracy: 0.9536
# 820th iteration, loss: 0.0482, test accuracy: 0.9564
# 830th iteration, loss: 0.0339, test accuracy: 0.9625
# 840th iteration, loss: 0.0623, test accuracy: 0.9581
# 850th iteration, loss: 0.0834, test accuracy: 0.9529
# 860th iteration, loss: 0.0807, test accuracy: 0.9560
# 870th iteration, loss: 0.1056, test accuracy: 0.9620
# 880th iteration, loss: 0.1666, test accuracy: 0.9576
# 890th iteration, loss: 0.0515, test accuracy: 0.9518
# 900th iteration, loss: 0.1555, test accuracy: 0.9550
# 910th iteration, loss: 0.1136, test accuracy: 0.9605
# 920th iteration, loss: 0.0747, test accuracy: 0.9632
# 930th iteration, loss: 0.1278, test accuracy: 0.9559
# 940th iteration, loss: 0.1375, test accuracy: 0.9602
# 950th iteration, loss: 0.1386, test accuracy: 0.9620
# 960th iteration, loss: 0.1453, test accuracy: 0.9525
# 970th iteration, loss: 0.1750, test accuracy: 0.9622
# 980th iteration, loss: 0.1410, test accuracy: 0.9590
# 990th iteration, loss: 0.0657, test accuracy: 0.9468
# 1000th iteration, loss: 0.0289, test accuracy: 0.9498
# 1010th iteration, loss: 0.1326, test accuracy: 0.9539
# 1020th iteration, loss: 0.1884, test accuracy: 0.9573
# 1030th iteration, loss: 0.0567, test accuracy: 0.9621
# 1040th iteration, loss: 0.0792, test accuracy: 0.9588
# 1050th iteration, loss: 0.1370, test accuracy: 0.9600
# 1060th iteration, loss: 0.1694, test accuracy: 0.9559
# 1070th iteration, loss: 0.0734, test accuracy: 0.9555
# 1080th iteration, loss: 0.0614, test accuracy: 0.9617
# 1090th iteration, loss: 0.0410, test accuracy: 0.9604
# 1100th iteration, loss: 0.1104, test accuracy: 0.9620
# 1110th iteration, loss: 0.0694, test accuracy: 0.9639
# 1120th iteration, loss: 0.1603, test accuracy: 0.9599
# 1130th iteration, loss: 0.0611, test accuracy: 0.9570
# 1140th iteration, loss: 0.0364, test accuracy: 0.9604
# 1150th iteration, loss: 0.0751, test accuracy: 0.9616
# 1160th iteration, loss: 0.0971, test accuracy: 0.9635
# 1170th iteration, loss: 0.0898, test accuracy: 0.9611
# 1180th iteration, loss: 0.0335, test accuracy: 0.9652
# 1190th iteration, loss: 0.1175, test accuracy: 0.9612
# 1200th iteration, loss: 0.1025, test accuracy: 0.9607
# 1210th iteration, loss: 0.1321, test accuracy: 0.9631
# 1220th iteration, loss: 0.1029, test accuracy: 0.9604
# 1230th iteration, loss: 0.0813, test accuracy: 0.9545
# 1240th iteration, loss: 0.1420, test accuracy: 0.9576
# 1250th iteration, loss: 0.0395, test accuracy: 0.9606
# 1260th iteration, loss: 0.0598, test accuracy: 0.9614
# 1270th iteration, loss: 0.1000, test accuracy: 0.9625
# 1280th iteration, loss: 0.0498, test accuracy: 0.9624
# 1290th iteration, loss: 0.0842, test accuracy: 0.9650
# 1300th iteration, loss: 0.0197, test accuracy: 0.9624
# 1310th iteration, loss: 0.0274, test accuracy: 0.9617
# 1320th iteration, loss: 0.0717, test accuracy: 0.9510
# 1330th iteration, loss: 0.2110, test accuracy: 0.9613
# 1340th iteration, loss: 0.1640, test accuracy: 0.9600
# 1350th iteration, loss: 0.0813, test accuracy: 0.9588
# 1360th iteration, loss: 0.0689, test accuracy: 0.9590
# 1370th iteration, loss: 0.0669, test accuracy: 0.9603
# 1380th iteration, loss: 0.0524, test accuracy: 0.9571
# 1390th iteration, loss: nan, test accuracy: 0.0980
# 1400th iteration, loss: nan, test accuracy: 0.0980
# 1410th iteration, loss: nan, test accuracy: 0.0980
# 1420th iteration, loss: nan, test accuracy: 0.0980
# 1430th iteration, loss: nan, test accuracy: 0.0980
# 1440th iteration, loss: nan, test accuracy: 0.0980
# 1450th iteration, loss: nan, test accuracy: 0.0980
# 1460th iteration, loss: nan, test accuracy: 0.0980
# 1470th iteration, loss: nan, test accuracy: 0.0980
# 1480th iteration, loss: nan, test accuracy: 0.0980
# 1490th iteration, loss: nan, test accuracy: 0.0980
# 1500th iteration, loss: nan, test accuracy: 0.0980
# 1510th iteration, loss: nan, test accuracy: 0.0980
# 1520th iteration, loss: nan, test accuracy: 0.0980
# 1530th iteration, loss: nan, test accuracy: 0.0980
# 1540th iteration, loss: nan, test accuracy: 0.0980
# 1550th iteration, loss: nan, test accuracy: 0.0980
# 1560th iteration, loss: nan, test accuracy: 0.0980
# 1570th iteration, loss: nan, test accuracy: 0.0980
# 1580th iteration, loss: nan, test accuracy: 0.0980
# 1590th iteration, loss: nan, test accuracy: 0.0980
# 1600th iteration, loss: nan, test accuracy: 0.0980
# 1610th iteration, loss: nan, test accuracy: 0.0980
# 1620th iteration, loss: nan, test accuracy: 0.0980
# 1630th iteration, loss: nan, test accuracy: 0.0980
# 1640th iteration, loss: nan, test accuracy: 0.0980
# 1650th iteration, loss: nan, test accuracy: 0.0980
# 1660th iteration, loss: nan, test accuracy: 0.0980
# 1670th iteration, loss: nan, test accuracy: 0.0980
# 1680th iteration, loss: nan, test accuracy: 0.0980
# 1690th iteration, loss: nan, test accuracy: 0.0980
# 1700th iteration, loss: nan, test accuracy: 0.0980
# 1710th iteration, loss: nan, test accuracy: 0.0980
# 1720th iteration, loss: nan, test accuracy: 0.0980
# 1730th iteration, loss: nan, test accuracy: 0.0980
# 1740th iteration, loss: nan, test accuracy: 0.0980
# 1750th iteration, loss: nan, test accuracy: 0.0980
# 1760th iteration, loss: nan, test accuracy: 0.0980
# 1770th iteration, loss: nan, test accuracy: 0.0980
# 1780th iteration, loss: nan, test accuracy: 0.0980
# 1790th iteration, loss: nan, test accuracy: 0.0980
# 1800th iteration, loss: nan, test accuracy: 0.0980
# 1810th iteration, loss: nan, test accuracy: 0.0980
# 1820th iteration, loss: nan, test accuracy: 0.0980
# 1830th iteration, loss: nan, test accuracy: 0.0980
# 1840th iteration, loss: nan, test accuracy: 0.0980
# 1850th iteration, loss: nan, test accuracy: 0.0980
# 1860th iteration, loss: nan, test accuracy: 0.0980
# 1870th iteration, loss: nan, test accuracy: 0.0980
# 1880th iteration, loss: nan, test accuracy: 0.0980
# 1890th iteration, loss: nan, test accuracy: 0.0980
# 1900th iteration, loss: nan, test accuracy: 0.0980
# 1910th iteration, loss: nan, test accuracy: 0.0980
# 1920th iteration, loss: nan, test accuracy: 0.0980
# 1930th iteration, loss: nan, test accuracy: 0.0980
# 1940th iteration, loss: nan, test accuracy: 0.0980
# 1950th iteration, loss: nan, test accuracy: 0.0980
# 1960th iteration, loss: nan, test accuracy: 0.0980
# 1970th iteration, loss: nan, test accuracy: 0.0980
# 1980th iteration, loss: nan, test accuracy: 0.0980
# 1990th iteration, loss: nan, test accuracy: 0.0980
# 2000th iteration, loss: nan, test accuracy: 0.0980

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1833814312997315757, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11191633409538163485
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4097103822432006590
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7691812864
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9648196376347792436
#  physical_device_desc: "device: 0, name: GeForce RTX 2080, pci bus id: 0000:17:00.0, compute capability: 7.5", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 7251204506
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 5954348776016190623
#  physical_device_desc: "device: 1, name: GeForce RTX 2080, pci bus id: 0000:b3:00.0, compute capability: 7.5"]
