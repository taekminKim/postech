# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#데이터 불러오기
ds_hmeq = pd.read_csv("../../실습화일/상품구매.csv", encoding='euc-kr')
ds_hmeq.head()
# Out:
#      ID    PRODUCT
# 0  C-11   BAGUETTE
# 1  C-11    HERRING
# 2  C-11    AVOCADO
# 3  C-11  ARTICHOKE
# 4  C-11   HEINEKEN

# %%
ds_hmeq = ~ds_hmeq.pivot(index="ID", columns="PRODUCT", values="PRODUCT").isnull()
ds_hmeq
# Out:
# PRODUCT  APPLES  ARTICHOKE  AVOCADO  BAGUETTE  BOURBON  CHICKEN   COKE  \
# ID
# C-11       True       True     True      True    False    False  False
# C-12       True      False    False     False    False    False  False
# C-13       True      False     True      True    False    False  False
# C-14       True      False    False     False    False    False   True
# C-15      False       True    False     False     True    False   True
# C-16      False       True     True      True    False    False   True
# C-17       True      False    False     False    False     True   True
# C-18      False      False    False      True     True    False  False
# C-19      False      False    False     False     True    False  False
# C-20       True      False    False      True    False    False  False
# C-21      False       True     True      True     True    False  False
# C-22      False       True    False     False     True    False  False
# C-23      False      False    False     False     True    False  False
# C-24       True      False    False      True    False     True   True
# C-25      False      False    False     False    False     True   True
# C-26       True      False    False      True     True    False   True
# C-27      False      False     True     False     True    False   True
# C-28      False       True    False     False     True    False  False
# C-29      False      False    False     False     True    False   True
# C-30      False      False    False     False     True    False   True
#
# PRODUCT  CORNED BEEF  CRACKERS    HAM  HEINEKEN  HERRING  ICE CREAM  OLIVES  \
# ID
# C-11            True     False  False      True     True      False   False
# C-12            True     False  False      True     True      False    True
# C-13           False     False  False     False    False       True   False
# C-14            True     False   True     False     True      False    True
# C-15           False     False   True     False    False       True    True
# C-16           False     False  False      True     True      False   False
# C-17            True     False  False      True    False       True   False
# C-18           False      True  False      True    False      False    True
# C-19           False      True  False      True     True      False    True
# C-20            True     False   True     False     True      False    True
# C-21            True     False  False      True     True      False   False
# C-22           False      True  False      True    False      False    True
# C-23            True      True  False      True     True      False    True
# C-24           False     False  False      True    False       True   False
# C-25            True     False  False      True    False       True   False
# C-26           False     False  False     False    False       True    True
# C-27           False     False  False     False    False       True    True
# C-28           False      True  False      True    False      False    True
# C-29           False     False  False     False    False       True    True
# C-30           False     False   True     False    False       True    True
#
# PRODUCT  PEPPERS  SARDINES   SODA  STEAK  TURKEY
# ID
# C-11       False     False  False  False   False
# C-12       False      True  False   True   False
# C-13        True      True  False   True   False
# C-14       False     False  False  False    True
# C-15       False     False  False  False    True
# C-16       False     False  False  False    True
# C-17       False      True  False  False   False
# C-18        True     False   True  False   False
# C-19       False     False   True   True   False
# C-20       False     False  False  False    True
# C-21       False     False  False  False   False
# C-22       False     False   True   True   False
# C-23       False     False   True  False   False
# C-24       False      True  False  False   False
# C-25        True      True  False  False   False
# C-26       False     False  False  False    True
# C-27       False     False   True  False    True
# C-28        True     False   True  False   False
# C-29       False      True   True  False    True
# C-30       False     False   True  False    True

# %%
#items 중 index 0번이 갖고 있으면 True, 아니면 False
enc = TransactionEncoder()
arr = enc.fit_transform(X= ds_hmeq)
#위의 함수는 데이터를 행렬의 형태로 반환 -> pandas의 DataFrame의 형태로 변환
ds_pre = pd.DataFrame(arr, columns = enc.columns_)
ds_pre
# Out:
#                A      B      C      D      E      F      G      H      I  \
# 0   False   True  False  False  False   True  False  False  False  False
# 1   False   True  False   True  False   True  False  False   True   True
# 2   False   True  False   True   True  False  False  False  False  False
# 3   False   True   True  False  False   True  False   True  False  False
# 4   False  False   True  False  False  False  False  False  False  False
# 5   False  False  False   True  False   True  False  False   True   True
# 6   False  False  False   True  False   True  False  False  False  False
# 7    True  False   True   True   True   True   True  False  False  False
# 8   False   True  False   True  False   True  False  False  False  False
# 9   False   True  False  False  False  False  False  False   True  False
# 10  False  False  False  False  False   True  False  False   True   True
# 11  False  False  False  False  False   True  False   True   True   True
# 12   True   True  False   True  False   True  False  False  False   True
# 13  False  False  False  False  False   True  False  False  False   True
# 14  False  False  False  False  False   True  False  False  False  False
# 15  False   True  False  False   True   True  False  False  False   True
# 16  False   True  False  False   True  False  False  False  False  False
# 17  False   True  False  False  False   True  False  False  False  False
# 18  False  False  False  False  False   True  False  False  False  False
# 19  False  False  False  False  False  False  False  False  False  False
#
#     ...        M      N      O      P      R      S      T      U      V  \
# 0   ...    False  False  False   True  False   True  False  False  False
# 1   ...    False  False   True  False   True  False   True  False  False
# 2   ...    False  False   True  False  False  False  False  False   True
# 3   ...    False  False  False  False  False  False   True   True  False
# 4   ...    False   True   True  False   True  False  False   True  False
# 5   ...    False   True  False  False  False  False  False  False  False
# 6   ...    False  False   True  False  False  False  False  False  False
# 7   ...    False   True   True  False   True  False  False  False  False
# 8   ...    False  False  False  False   True   True  False  False  False
# 9   ...     True  False  False  False  False  False  False  False  False
# 10  ...    False   True  False  False  False  False  False  False  False
# 11  ...    False   True  False  False   True  False  False  False  False
# 12  ...     True  False  False  False   True  False  False  False  False
# 13  ...    False  False   True  False  False   True  False  False   True
# 14  ...    False  False  False   True   True   True  False  False  False
# 15  ...    False   True  False  False   True   True  False  False  False
# 16  ...    False  False   True  False  False   True  False  False  False
# 17  ...    False  False  False  False  False   True   True  False  False
# 18  ...    False  False  False  False   True  False   True   True  False
# 19  ...    False  False  False  False  False  False  False  False  False
#
#         Y
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18   True
# 19  False
#
# [20 rows x 22 columns]

# %%
#최소 지지도
min_support = 0.3

#지지도 계산
ds_freq = apriori(ds_pre, min_support = min_support, use_colnames = True)
ds_freq.round(3)
# Out:
#     support itemsets
# 0      0.50      (A)
# 1      0.35      (C)
# 2      0.75      (E)
# 3      0.35      (I)
# 4      0.35      (K)
# 5      0.30      (N)
# 6      0.35      (O)
# 7      0.45      (R)
# 8      0.35      (S)
# 9      0.35   (E, A)
# 10     0.30   (E, C)
# 11     0.35   (E, I)
# 12     0.35   (K, E)
# 13     0.40   (E, R)
# 14     0.30   (E, S)

# %%
#기준 = 신뢰도, 최소 신뢰도 = 0.5
ds_asso_rule = association_rules(ds_freq, metric = "confidence", min_threshold = 0.5)
ds_asso_rule.round(3)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0         (A)         (E)                0.50                0.75     0.35
# 1         (I)         (E)                0.35                0.75     0.35
# 2         (C)         (E)                0.35                0.75     0.30
# 3         (K)         (E)                0.35                0.75     0.35
# 4         (E)         (R)                0.75                0.45     0.40
# 5         (R)         (E)                0.45                0.75     0.40
# 6         (S)         (E)                0.35                0.75     0.30
#
#    confidence   lift  leverage  conviction
# 0       0.700  0.933    -0.025    0.833000
# 1       1.000  1.333     0.088         inf
# 2       0.857  1.143     0.038    1.750000
# 3       1.000  1.333     0.088         inf
# 4       0.533  1.185     0.062    1.179000
# 5       0.889  1.185     0.062    2.250000
# 6       0.857  1.143     0.038    1.750000
